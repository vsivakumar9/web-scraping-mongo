# %% [markdown]
# # Web scraping to get data for the Mars Mission.

# %%
# Dependencies
from bs4 import BeautifulSoup
from splinter import Browser
import requests
import pymongo

# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Scrape information from https://mars.nasa.gov/news/. class is "content_title' for news title.
#Class is class="article_teaser_body" for para text. 
url1="https://mars.nasa.gov/news/"
# Retrieve page and html info  with the requests module.
response = requests.get(url1)

# %%
# Create soup object to parse resultant html. 
soup =  BeautifulSoup(response.text, 'html.parser')
#print(soup.prettify())

# %%
soupx =  BeautifulSoup(response.text, 'lxml')
print(soup2.prettify())

# %%
# Get title and text for the latest news.class is "content_title' for news title. 
# Class is class="article_teaser_body" for para text. 

results_ul = soup.find('ul',class_="item_list" )

result_title = soup.find('div', class_="content_title")
#print(result_title)
news_title = result_title.text
print(news_title)

#title = result.find('a', class_="result-title").text
result_para   = soup.find_all('div', class_="rollover_description_inner")
#for r in result_para:
#    print(r)
# Out:
# Opportunity Hunkers Down During Dust Storm

# %%
## Mars space images 
#* Visit the url for JPL Featured Space Image [here](https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars).
#* Use splinter to navigate the site and find the image url for the current Featured Mars Image and assign the url string to a 
#* variable called `featured_image_url`.
#* Make sure to find the image url to the full size `.jpg` image.
#* Make sure to save a complete url string for this image.
url2="https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars"
response2 = requests.get(url2)

# %%
#Use beautiful soup to parse the html.
soup2 = BeautifulSoup(response2.text, 'html.parser')

# %%
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 9]> <html class="no-js ie ie9" lang="en"> <![endif]-->
# <!--[if IE 8]> <html class="no-js ie ie8" lang="en"> <![endif]-->
# <html>
#  <!-- START HEADER: "DEFAULT" -->
#  <head>
#   <meta charset="utf-8"/>
#   <!-- Always force latest IE rendering engine or request Chrome Frame -->
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <title>
#    Space Images
#   </title>
#   <link href="/assets/stylesheets/manifest.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="/assets/stylesheets/print.css" media="print" rel="stylesheet" type="text/css"/>
#   <script src="/assets/javascripts/public_manifest.js" type="text/javascript">
#   </script>
#   <script src="/assets/javascripts/vendor/jquery.fancybox.js" type="text/javascript">
#   </script>
# ...

# %%
## parse li with class of slide. <a tag with fanybox has the partial xref. Need to concat 
urla="https://www.jpl.nasa.gov"
resultli = soup2.find('li', class_="slide")
#print(resultli)

link = resultli.a['data-fancybox-href']
print(link)

feat_url = urla + link
print(feat_url)
# Out:
# /spaceimages/images/largesize/PIA22624_hires.jpg
# https://www.jpl.nasa.gov/spaceimages/images/largesize/PIA22624_hires.jpg

# %%
#media_feature_title - get the featured image url. <a tag, class = "button fancybox".  Use splinter..
##data-fancybox-href="/spaceimages/images/mediumsize/PIA19913_ip.jpg"
## results = soup.find_all('li', class_="result-row")
#result2 = soup2.find_all('ul',class_="articles")
#for r in result2:
    #print(r.text)
#print(result1.a.text)

#link = result2.a['href']
#print(link)

# %%
#define exec path for chromedriver.exe.

executable_path = {'executable_path': 'C:\ChromeSafe\chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)
#Define url and browse the site using chrome. 
url = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
#Find footer and the href. 
urla="https://www.jpl.nasa.gov"

foot = soup.find('footer')
link = foot.a['data-fancybox-href']
feat_url = urla + link
print(feat_url)
# Out:
# https://www.jpl.nasa.gov/spaceimages/images/mediumsize/PIA00063_ip.jpg
